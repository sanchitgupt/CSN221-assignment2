# %% [markdown]
# <a href="https://colab.research.google.com/github/sanchitgupt/CSN221-assignment2/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -l -s git://github.com/deepfakes/faceswap faceswap
# %cd faceswap
# !ls
# Out:
# Cloning into 'faceswap'...
# ...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 6924 (delta 3), reused 10 (delta 2), pack-reused 6905
# Receiving objects: 100% (6924/6924), 193.74 MiB | 32.81 MiB/s, done.
# Resolving deltas: 100% (4783/4783), done.
# /content/faceswap
# CODE_OF_CONDUCT.md  docs	 plugins	   setup.py	   USAGE.md
# config		    faceswap.py  README.md	   tools
# _config.yml	    INSTALL.md	 requirements.txt  tools.py
# Dockerfile.cpu	    lib		 scripts	   _travis
# Dockerfile.gpu	    LICENSE	 setup.cfg	   update_deps.py

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip install imageio-ffmpeg
# Out:
# ...
#      |████████████████████████████████| 22.2MB 49.0MB/s
# ...

# %%
# !pip install moviepy
# !pip install fastcluster
# Out:
# ...
#      |████████████████████████████████| 163kB 4.8MB/s
# ...

# %%
# !python faceswap.py extract -i /content/faceswap/src/sanyam.mp4 -o /content/faceswap/faces/sanyam
# Out:
# First time configuration. Please select the required backend
# 1: AMD, 2: CPU, 3: NVIDIA: 3
# Faceswap config written to: /content/faceswap/config/.faceswap
# Setting Faceswap backend to NVIDIA
# 03/11/2020 04:37:21 INFO     Log level set to: INFO
# 03/11/2020 04:37:23 INFO     Output Directory: /content/faceswap/faces/sanyam
# 03/11/2020 04:37:23 INFO     Loading Detect from S3Fd plugin...
# 03/11/2020 04:37:23 INFO     Downloading model: 's3fd_keras' from: https://github.com/deepfakes-models/faceswap-models/releases/download/v1.11.1/s3fd_keras_v1.zip
# Downloading: 100% 11.1M/11.1M [00:00<00:00, 17.8MB/s]
# 03/11/2020 04:37:24 INFO     Extracting: 's3fd_keras'
# Decompressing: 100% 85.9M/85.9M [00:00<00:00, 164MB/s]
# 03/11/2020 04:37:25 INFO     Loading Align from Fan plugin...
# ...

# %%
# !python faceswap.py extract -i /content/faceswap/src/sanchit.mp4 -o /content/faceswap/faces/sanchit
# Out:
# Setting Faceswap backend to NVIDIA
# 03/11/2020 04:40:53 INFO     Log level set to: INFO
# 03/11/2020 04:40:55 INFO     Output Directory: /content/faceswap/faces/sanchit
# 03/11/2020 04:40:55 INFO     Loading Detect from S3Fd plugin...
# 03/11/2020 04:40:55 INFO     Loading Align from Fan plugin...
# 03/11/2020 04:40:55 INFO     Loading Mask from Extended plugin...
# 03/11/2020 04:40:55 INFO     Starting, this may take a while...
# 03/11/2020 04:40:55 INFO     Initializing S3FD (Detect)...
# 03/11/2020 04:40:56 WARNING  Warning: the frame size for reading (1080, 1920) is different from the source frame size (1920, 1080).
# 03/11/2020 04:40:57 INFO     Initialized S3FD (Detect) with batchsize of 4
# 03/11/2020 04:40:57 INFO     Initializing FAN (Align)...
# 03/11/2020 04:41:14 INFO     Initialized FAN (Align) with batchsize of 12
# 03/11/2020 04:41:14 INFO     Initializing Extended (Mask)...
# 03/11/2020 04:41:14 INFO     Initialized Extended (Mask) with batchsize of 1
# ...

# %%
# !python faceswap.py train -A /content/faceswap/faces/sanyam -B /content/faceswap/faces/sanchit -m /content/faceswap/trump_cage_model/
# Out:
# Setting Faceswap backend to NVIDIA
# 03/11/2020 04:44:48 INFO     Log level set to: INFO
# Using TensorFlow backend.
# 03/11/2020 04:44:50 INFO     Model A Directory: /content/faceswap/faces/sanyam
# 03/11/2020 04:44:50 INFO     Model B Directory: /content/faceswap/faces/sanchit
# 03/11/2020 04:44:50 INFO     Training data directory: /content/faceswap/trump_cage_model
# 03/11/2020 04:44:50 INFO     ===================================================
# 03/11/2020 04:44:50 INFO       Starting
# 03/11/2020 04:44:50 INFO       Press 'ENTER' to save and quit
# 03/11/2020 04:44:50 INFO       Press 'S' to save model weights immediately
# 03/11/2020 04:44:50 INFO     ===================================================
# 03/11/2020 04:44:51 INFO     Loading data, this may take a while...
# 03/11/2020 04:44:51 INFO     Loading Model from Original plugin...
# 03/11/2020 04:44:51 INFO     No existing state file found. Generating.
# ...

# %%
# !python faceswap.py convert -i /content/faceswap/faces/sanyam/ -o /content/faceswap/converted/ -m /content/faceswap/trump_cage_model/
# Out:
# Setting Faceswap backend to NVIDIA
# 03/10/2020 15:21:07 INFO     Log level set to: INFO
# Using TensorFlow backend.
# 03/10/2020 15:21:09 INFO     Input Directory: /content/faceswap/faces/sanyam
# 03/10/2020 15:21:09 INFO     Loading Writer from Opencv plugin...
# 03/10/2020 15:21:09 ERROR    No alignments file found. Please provide an alignments file for your destination video (recommended) or enable on-the-fly conversion (not recommended).
